# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import json

# %% [markdown]
# Read the data

# %%
business_data = []
with open('data/yelp_academic_dataset_business.json') as f:
    for line in f:
        business_data.append(json.loads(line))
business_df = pd.DataFrame.from_dict(business_data)

business_df = business_df[business_df["state"] == "PA"]

# %%
business_df
# Out:
#                    business_id                                 name  \
# 3       MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA             Perkiomen Valley Brewery
# 15      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 25      PSo_C1Sfa13JHjzVNW6ziQ        Indian Walk Veterinary Center
# ...                        ...                                  ...
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                                 Wawa
# 150326  JDM7kiCEmeBc_5W-z6eZZw              2601 Parkway Apartments
# 150329  9U1Igcpe954LoWZRmNc-zg  Hand & Stone Massage And Facial Spa
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ             Shanti Yoga and Ayurveda
# 150336  WnT9NIzQgLlILjPT0kEcsQ        Adelita Taqueria & Restaurant
#
#                              address             city state postal_code  \
# 3                        935 Race St     Philadelphia    PA       19107
# ...

# %%
business_df.dropna(subset='categories', inplace=True)
business_df.reset_index(drop=True, inplace=True)

# %%
business_df
# Out:
#                   business_id                                 name  \
# 0      MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 1      mWMc6_wTdE0EUBKIGXDVfA             Perkiomen Valley Brewery
# 2      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 3      ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 4      PSo_C1Sfa13JHjzVNW6ziQ        Indian Walk Veterinary Center
# ...                       ...                                  ...
# 34008  l9eLGG9ZKpLJzboZq-9LRQ                                 Wawa
# 34009  JDM7kiCEmeBc_5W-z6eZZw              2601 Parkway Apartments
# 34010  9U1Igcpe954LoWZRmNc-zg  Hand & Stone Massage And Facial Spa
# 34011  LJ4GjQ1HL6kqvIPpNUNNaQ             Shanti Yoga and Ayurveda
# 34012  WnT9NIzQgLlILjPT0kEcsQ        Adelita Taqueria & Restaurant
#
#                             address             city state postal_code  \
# 0                       935 Race St     Philadelphia    PA       19107
# ...

# %%
cat_data = pd.read_csv('data/categories.csv', header=None)
categories = cat_data[0].tolist()
businesses_pa_df = pd.DataFrame()
for index, item in business_df['categories'].items():
    for category in categories:
        if category in item:
            businesses_pa_df = pd.concat([businesses_pa_df, business_df[index:index+1]])
            break

# %%
businesses_pa_df
# Out:
#                   business_id                           name  \
# 0      MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1      mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery
# 2      MUTTqe8uqyMdBl186RmNeA                       Tuna Bar
# 3      ROeacJQwBeh05Rqg7F6TCg                            BAP
# 5      QdN72BWoyFypdGJhhI5r7g                        Bar One
# ...                       ...                            ...
# 34002  gPr1io7ks0Eo3FDsnDTYfg                      Tata Cafe
# 34003  wVxXRFf10zTTAs11nr4xeA                   PrimoHoagies
# 34006  8n93L-ilMAsvwUatarykSg                    Kitchen Gia
# 34008  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 34012  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
#
#                    address             city state postal_code   latitude  \
# 0              935 Race St     Philadelphia    PA       19107  39.955505
# 1            101 Walnut St       Green Lane    PA       18054  40.338183
# ...

# %%
arr_df = pd.json_normalize(business_df['attributes'])
business_df = pd.concat([business_df, arr_df], axis =1)

arr_df = pd.json_normalize(business_df['attributes'])
businesses_pa = business_df.drop(['address', 'city', 'state', 'postal_code','ByAppointmentOnly',
'BikeParking',
'CoatCheck',
'Caters',
'WiFi',
'WheelchairAccessible',
'HappyHour',
'HasTV',
'DogsAllowed',
'RestaurantsAttire',
'GoodForMeal',
'BusinessAcceptsBitcoin',
'Smoking',
'Music',
'GoodForDancing',
'AcceptsInsurance',
'BestNights',
'BYOB',
'Corkage',
'BYOBCorkage',
'HairSpecializesIn',
'AgesAllowed'],axis=1)

# %%
businesses_pa

# %%
cat_data = pd.read_csv('data/categories.csv', header=None)
categories = cat_data[0].tolist()
businesses_pa_df = pd.DataFrame()
for index, item in businesses_pa['categories'].items():
    for category in categories:
        if category in item:
            businesses_pa_df = pd.concat([businesses_pa_df, businesses_pa[index:index+1]])
            break

# %%
businesses_pa

# %%
businesses_pa.drop_duplicates(subset=['business_id'])

# %%
business_df_new.head()

# %%
# Seperate category columns
category_sep = business_df['categories'].str.split(',').apply(pd.Series)
business_df = pd.concat([business_df, category_sep], axis=1)
business_df

# %%
# Count unique value of category
category_all = category_sep.stack().unique()
category_all

for category in category_all:
    print(category)

# %%
# Save category to CSV locally
category_all_df = pd.DataFrame(category_all)
category_all_df.to_csv("data1.csv")

# %%
arr_df = pd.json_normalize(business_df['attributes'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/siningd/sining/da-yelp-project/playground_sining.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/Users/siningd/sining/da-yelp-project/playground_sining.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> arr_df = pd.json_normalize(business_df['attributes'])
#
# NameError: name 'business_df' is not defined

# %%
arr_df

# %%
arr_json = arr_df.to_json(orient='records')
arr_df = pd.read_json(arr_json)
parking = pd.json_normalize(arr_df['BusinessParking'])

# %%
arr_df.info()

# %%
arr_df = pd.read_json(arr_json)

# %%
business_df

# %%
parking_df = arr_df['BusinessParking'].apply(lambda x: pd.Series(x))
parking_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/siningd/sining/da-yelp-project/playground_sining.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/Users/siningd/sining/da-yelp-project/playground_sining.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> parking_df = arr_df['BusinessParking'].apply(lambda x: pd.Series(x))
#       <a href='vscode-notebook-cell:/Users/siningd/sining/da-yelp-project/playground_sining.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> parking_df
#
# NameError: name 'arr_df' is not defined

# %%
business_df = pd.concat([business_df, arr_df['BusinessParking'].apply(lambda x: pd.Series(x))], axis=1)

# %%
pip install ijson
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 kB 1.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 分块读取数据
chunk_size = 10000  # 每个块的大小
chunks = pd.read_json('data/yelp_academic_dataset_review.json', lines=True, chunksize=chunk_size)

for chunk in chunks:
    # 在这里处理每个数据块 (chunk)
    print(chunk)
# Out:
#                    review_id                 user_id             business_id  \
# 0     KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1     BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2     saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3     AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4     Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# ...                      ...                     ...                     ...
# 9995  ZcBtCA9jGhLfakf1jJ2BAg  yab1cq5yzrTHzoyz8LYqYQ  1-z7wd860Rii4kbEMCT8DA
# 9996  UIkEO-10J6Y99IhRqUflvg  lYAmgL_l7A3MPFYe1DYKrw  EpREWeEpmR8f1qLHzzF0AA
# 9997  S-NQM3Axcg8JS3MXHUIvyw  rE2WwfgJbYfvDwBlgq__dQ  dvidzWEPgTQPeBc8CUV2OQ
# 9998  ME79YrEhm2xe4IQy_0zkGw  OnIklvzKDpk1BduC84TrTA  2XYPFRm7teCUr3eGsB2-qw
# 9999  05oKtleZ-JFGD6qt47VQcg  p0MhNWkwOPBfRo8qUb7faw  rnaE88k8yV5pFAGJeiIK4Q
#
#       stars  useful  funny  cool  \
# ...

# %%
pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/siningd/sining/da-yelp-project/playground_sining.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/Users/siningd/sining/da-yelp-project/playground_sining.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> pd.set_option('display.max_columns', None)
#
# NameError: name 'pd' is not defined

# %%
data_review = []

with open('data/yelp_academic_dataset_review.json') as r:

    for line in r:
        json_dict = json.loads(line)

        if json_dict['business_id']:

            for id in businesses_pa_id: 

                if id in json_dict['business_id']:

                    data_review.append(json_dict)
